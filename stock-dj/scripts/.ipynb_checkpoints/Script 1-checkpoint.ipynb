# %%
print "hello world"
# Out:
# hello world

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_AAPL = pd.read_csv("../stock-data-dow-jones/AAPL.csv")
data_AAPL.head()
# Out:
#          date     open     high      low    close     volume  \
# 0  2014-01-27  72.1199  72.7401  71.5535  72.1763  144219152
# 1  2014-01-28  66.7037  67.5219  65.8266  66.4074  266833581
# 2  2014-01-29  66.0731  66.5215  65.3743  65.6535  125942796
# 3  2014-01-30  65.8882  66.4074  65.1226  65.5266  169762789
# 4  2014-01-31  64.9233  65.7558  64.7096  65.6339  116336444
#
#    unadjustedVolume    change  changePercent     vwap       label  \
# 0          20602736  0.580818          0.811  70.6687  Jan 27, 14
# 1          38119083 -5.768900         -7.993  66.7869  Jan 28, 14
# 2          17991828 -0.753887         -1.135  65.8259  Jan 29, 14
# 3          24251827 -0.126916         -0.193  71.9614  Jan 30, 14
# 4          16619492  0.107251          0.164  71.6528  Jan 31, 14
#
#    changeOverTime
# 0        0.000000
# 1       -0.079928
# 2       -0.090373
# 3       -0.092131
# 4       -0.090645

# %%
print data_AAPL["date"]
# Out:
# 0       2014-01-27
# 1       2014-01-28
# 2       2014-01-29
# 3       2014-01-30
# 4       2014-01-31
# 5       2014-02-03
# 6       2014-02-04
# 7       2014-02-05
# 8       2014-02-06
# 9       2014-02-07
# 10      2014-02-10
# 11      2014-02-11
# 12      2014-02-12
# 13      2014-02-13
# 14      2014-02-14
# 15      2014-02-18
# 16      2014-02-19
# 17      2014-02-20
# 18      2014-02-21
# 19      2014-02-24
# 20      2014-02-25
# 21      2014-02-26
# 22      2014-02-27
# 23      2014-02-28
# 24      2014-03-03
# 25      2014-03-04
# 26      2014-03-05
# 27      2014-03-06
# 28      2014-03-07
# 29      2014-03-10
#            ...
# 1229    2018-12-12
# 1230    2018-12-13
# 1231    2018-12-14
# 1232    2018-12-17
# 1233    2018-12-18
# 1234    2018-12-19
# 1235    2018-12-20
# 1236    2018-12-21
# 1237    2018-12-24
# 1238    2018-12-26
# 1239    2018-12-27
# 1240    2018-12-28
# 1241    2018-12-31
# 1242    2019-01-02
# 1243    2019-01-03
# 1244    2019-01-04
# ...

# %%
data_AAPL.plot()
plt.show()

# %%
data_AAPL["open"].plot(grid=True,figsize=(10,5),)
data_AAPL["close"].plot(grid=True,figsize=(10,5))
plt.show()

# %%
opening=data_AAPL["open"]
print opening.mean()
closing=data_AAPL["close"]
print closing.mean()
# Out:
# 127.757066878
# 127.77846664

# %%
print opening[1]
# Out:
# 66.7037

# %%
print opening[0]
# Out:
# 72.1199

# %%
for a in opening:
    for b in closing:
        c=a-b
        print c
# Out:
# -0.0564
# 5.7125
# 6.4664
# 6.5933
# 6.486
# 6.3641
# 5.4122
# 4.914
# 4.5223
# 3.5766
# 2.3487
# 1.4293
# 1.4346
# 0.3122
# 0.3702
# 0.1064
# 1.2434
# 2.0638
# 2.8419
# 2.5386
# 3.2627
# 3.8839
# 2.5228
# 2.7114
# 2.5109
# 2.0519
# 1.9042
# 2.1165
# 2.1574
# 2.0941
# 1.4122
# 1.3436
# 2.1297
# 2.9158
# 2.6454
# 2.0308
# 2.0493
# 2.3869
# 1.8369
# 1.0033
# 0.2383
# 0.9255
# 1.2315
# 1.3106
# 1.3265
# 0.6789
# 0.5602
# 1.0561
# 1.9754
# 3.0767
# 3.0807
# 2.1732
# 3.0754
# 3.5858
# 3.3128
# 3.8035
# 3.665
# 2.8828
# 2.0611
# 1.9913
# 2.9079
# -2.7662
# -3.3162
# -6.2377
# -6.0056
# -5.7101
# -5.8935
# -6.0386
# -7.1438
# -6.2799
# -6.0056
# -5.4947
# -5.1716
# -6.1336
# -6.2564
# -6.2709
# -5.6043
# -6.7514
# -7.6859
# -7.7018
# -7.913
# -8.0397
# -8.9452
# -10.4632
# -10.2493
# -11.7502
# -11.436
# -10.8618
# -12.0353
# -12.9963
# -13.3302
# -13.0953
# -14.4589
# -14.9671
# -14.6067
# -13.156
# -12.2228
# -13.0729
# -12.962
# -13.0544
# -12.7587
# -11.8809
# -11.807
# -11.2988
# ...

# %%
c=opening-closing
c.plot(grid=True,figsize=(10,5))
plt.show()

# %%
data_AAPL_open_index = data_AAPL
data_AAPL_open_index.set_index("open", inplace=True)
data_AAPL_open_index["close"].plot(figsize=(10,10))
plt.show()
